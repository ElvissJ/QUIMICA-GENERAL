# %% [markdown]
# <a href="https://colab.research.google.com/github/ElvissJ/QUIMICA-GENERAL/blob/main/Copia_de_Gases_continuacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Actividad: Realizar las medidas de tendencia central y compararlas para explicar la siguientes gráficas.

# %% [markdown]
# ![borrame.png](data:image/png;base64,...)

# %% [markdown]
# Apellidos y nombres: Jacho Llocclla Elvis Osmar
# código: 23190123

# %%
import pandas as pd
import math
# Datos
Temperaturas = [100, 300, 700]
Constante_Boltzmann = 1.38e-23
Masa_N2 = 28
Numero_Avogadro = 6.0221e23
Presion = 1.0
Volumen = 1.0

data = []
for Temp in Temperaturas:
    n = (Presion * Volumen) / (8.314 * Temp)
    Numero_moleculas = n * Numero_Avogadro

    Velocidad = math.sqrt((3 * Constante_Boltzmann * Temp) / (Masa_N2 * 1.60218e-27))

    data.append([Temp, Velocidad, Numero_moleculas])

df = pd.DataFrame(data, columns=['Temperatura (K)','Velocidad (m/s)','Cantidad de Moléculas de N2'])

# Mostrar la tabla en Colab
df
# Out:
#    Temperatura (K)  Velocidad (m/s)  Cantidad de Moléculas de N2
# 0              100       303.784424                 7.243325e+20
# 1              300       526.170056                 2.414442e+20
# 2              700       803.738037                 1.034761e+20

# %%
import numpy as np
import matplotlib.pyplot as plt
D_e = ['100 K', '300 k', '700 k']
D_s = [303.784424, 526.170056, 803.738037]
plt.bar(D_e, D_s, color = "orange")
plt.xticks(rotation=90)
plt.show();

# %% [markdown]
# Se observa que a medida que se aumenta la temperatura, más moléculas se mueven a mayores velocidades. Es decir son directamente proporcionales. Además se evidencia que la media de la velocidad es la que hallamos mediante la fórmula usando la constante de Boltzmann. En el gráfico la media es hallada al sumar las velocidades mínimas y las máximas para cada temperatura, y dividirlas por el número de párticulas. Gráficamente sería como partir las curvas en dos partes iguales, y el valor del que sale la línea que las divide es la media. La mediana tiene el mismo valor que la media, ya que no importa el orden con el que se midan las partículas, pues estas son iguales. La distribución es simétrica. En cuánto a la moda, es la velocidad que adquiere el mayor número de moléculas. gráficamente sería el valor del que sale la línea que pasa por el valor máximo del número de partículas de la gráfica.

# %%
import pandas as pd
import math
# Datos
Masas = [70.90, 28.02, 4.003]
Constante_Boltzmann = 1.38e-23
Temperatura = 300
Numero_Avogadro = 6.0221e23
Presion = 1.0
Volumen = 1.0

data = []
for Mass in Masas:
    n = (Presion * Volumen) / (8.314 * 300)
    Numero_moleculas = n * Numero_Avogadro

    Velocidad = math.sqrt((3 * Constante_Boltzmann * 300) / (Mass * 1.60218e-27))

    data.append([Mass, Velocidad, Numero_moleculas])

df = pd.DataFrame(data, columns=['Masa molecular (g/mol)','Velocidad (m/s)','Cantidad de Moléculas'])

# Mostrar la tabla en Colab
df
# Out:
#    Masa molecular (g/mol)  Velocidad (m/s)  Cantidad de Moléculas
# 0                  70.900       330.660279           2.414442e+20
# 1                  28.020       525.982239           2.414442e+20
# 2                   4.003      1391.593366           2.414442e+20

# %%
import numpy as np
import matplotlib.pyplot as plt
D_e = ['70.90 g/mol', '28.02 g/mol', '4.003 g/mol']
D_s = [330.660279, 525.982239, 1391.593366]
plt.bar(D_e, D_s, color = "purple")
plt.xticks(rotation=90)
plt.show();

# %% [markdown]
# Se observa que a temperatura constante, las moléculas más ligeras (de menor masa molecular) se mueven con mayor rapidez. Es decir son inversamente proporcionales. Además se evidencia que la media de la velocidad es la que hallamos mediante la fórmula usando la constante de Boltzmann. En el gráfico la media es hallada al sumar las velocidades mínimas y las máximas para cada molécula, y dividirlas por el número de párticulas. Gráficamente sería como partir las curvas en dos partes iguales, y el valor del que sale la línea que las divide es la media. La mediana tiene el mismo valor que la media, ya que no importa el orden con el que se midan las partículas, pues estas son iguales. La distribución es simétrica. En cuánto a la moda, es la velocidad que adquiere el mayor número de moléculas. gráficamente sería el valor del que sale la línea que pasa por el valor máximo del número de partículas de la gráfica.
